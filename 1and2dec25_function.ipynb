# %%
- Function without argument
- Function with argument
- Function with defualt argument

# %% [markdown]
# - Local variables and Global variables

# %% [markdown]
# - local variables define inside the function
#   - local variables can not use outside function
#    - Addition is local varibable concept
#    - variable sum is can not print outside
# - global variables define outside the function
#     - global variables can be use anywhere in entire code
#     - global variables can be use muiltple functions

# %%
def ADDITION():
    n1 = 10
    n2 =20
    n3 =30
    sum_number= n1 + n2 + n3
    print (f'sum of {n1} , {n2} and {n3} is {sum_number}')

# %%
ADDITION()
# Out:
# sum of 10 , 20 and 30 is 60

# %%
n11 = 10
n22 =20
n33 =30
def ADDITION1():
    sum1= n11 + n22 + n33
    print (f'sum of {n11} , {n22} and {n33} is {sum1}')

ADDITION1()
# Out:
# sum of 10 , 20 and 30 is 60

# %%
n1            # this is local variable hence getting the error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 n1
#
# NameError: name 'n1' is not defined

# %%
sum_number         # this is local variable hence getting the error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sum_number
#
# NameError: name 'sum_number' is not defined

# %%
n11    # this is global variable hence getting the o/p
# Out:
# 10

# %%
sum1   # this is local variable hence getting the error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sum1
#
# NameError: name 'sum1' is not defined

# %% [markdown]
# we can make local variable as global by making global keyword to that variable

# %%
n11 = 10
n22 =20
n33 =30
def ADDITION2(n1):
    global sum2
    sum2= n11 + n22 + n33
    print (f'sum of {n11} , {n22} and {n33} is {sum2}')

ADDITION2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6     sum2= n11 + n22 + n33
#       7     print (f'sum of {n11} , {n22} and {n33} is {sum2}')
# ----> 9 ADDITION2()
#
# TypeError: ADDITION2() missing 1 required positional argument: 'n1'

# %%
sum2
# Out:
# 60

# %%
def ADDITION3():
    n12 = 10
    n23 =20
    n34 =30
    sum_number2= n12 + n23 + n34
    print (f'sum of {n12} , {n23} and {n34} is {sum_number2}')

# %%
n12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 n12
#
# NameError: name 'n12' is not defined

# %%
def ADDITION3():
    global n12
    n12 = 10
    n23 =20
    n34 =30
    sum_number2= n12 + n23 + n34
    print (f'sum of {n12} , {n23} and {n34} is {sum_number2}')

# %%
ADDITION3()
# Out:
# sum of 10 , 20 and 30 is 60

# %%
n12
# Out:
# 10

# %% [markdown]
# - Unbound local error
# -  whenever same variable define as global as well as local, pyhton consider local variable first

# %%
def f1():
    print(y)
    y=10
f1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[29], line 4
#       2     print(y)
#       3     y=10
# ----> 4 f1()
#
# Cell In[29], line 2, in f1()
#       1 def f1():
# ----> 2     print(y)
#       3     y=10
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
z=100     #global
def f2():
    print(z)
    z=10       #local
f2()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[32], line 5
#       3     print(z)
#       4     z=10
# ----> 5 f2()
#
# Cell In[32], line 3, in f2()
#       2 def f2():
# ----> 3     print(z)
#       4     z=10
#
# UnboundLocalError: cannot access local variable 'z' where it is not associated with a value

# %%
z1=100     #global
def f3():
    z1=10       #local
    print(z1)
f3()
# Out:
# 10

# %%
summ=0
def Addition():
    n1=10
    n2=20
    summ =n1+n2
    print(f'summ is {summ}')

Addition()
# Out:
# summ is 30

# %%
summ
# Out:
# 0

# %% [markdown]
# - If we want to check summ as global then we have to declare summ as global keyword
# - Scan first but dont say
# - def func - no error but calling func will give error if any error

# %%
summ=0
def Addition():
    global summ
    n1=10
    n2=20
    summ =n1+n2
    print(f'summ is {summ}')

Addition()
# Out:
# summ is 30

# %%
summ
# Out:
# 30

# %%
summ1=0
def Addition1():
    n1=10
    n2=20
    summ1 = summ1+n2
    print(f'summ1 is {summ1}')

Addition1()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[38], line 8
#       5     summ1 = summ1+n2
#       6     print(f'summ1 is {summ1}')
# ----> 8 Addition1()
#
# Cell In[38], line 5, in Addition1()
#       3 n1=10
#       4 n2=20
# ----> 5 summ1 = summ1+n2
#       6 print(f'summ1 is {summ1}')
#
# UnboundLocalError: cannot access local variable 'summ1' where it is not associated with a value

# %%
summ2=0
def Addition2():
    n1=10
    n2=20
    c = summ2+n2
    print(f'summ1 is {c}')

Addition2()
# Out:
# summ1 is 20

# %%
def Add():
    p=100
    q=200
    r=300
    s= p + q+ r
    print(s)
Add()
# Out:
# 600

# %%
p =200
def Add():
    p=100
    q=200
    r=300
    s= p + q+ r
    print(s)
Add()
# Out:
# 600

# %%
def Add4():
    p=100
    q=200
    r=300
    s= pp + q+ r
    print(s)
pp =200
Add4()
# Out:
# 700

# %% [markdown]
# - define function
# - call function
# - run function
# - same varibale present for both local and gloabl then every time local variable prefernce is first
# - if we assign later and operation is perform first in case of local and global variable conficts then will get error

# %%
p=100
def sum3(p=200):
    q=300
    r=400
    s=p+q+r
    print(s)
p=500

sum3(p=400)

# 100 -> 200 -> 500 -> 400 ->latest  400 while running
# Out:
# 1100

# %%
t=100
def checkerror():
    q=300
    r=400
    s=t+q+r
    t=1000
    print(s)
t=500

checkerror()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 10
#       7     print(s)
#       8 t=500
# ---> 10 checkerror()
#
# Cell In[18], line 5, in checkerror()
#       3 q=300
#       4 r=400
# ----> 5 s=t+q+r
#       6 t=1000
#       7 print(s)
#
# UnboundLocalError: cannot access local variable 't' where it is not associated with a value

# %%
x=100
def sum6(x=200):
    x=1000
    q=300
    r=400
    s=x+q+r
    print(s)
x=500

sum6(x=400)

#100 ->200-> 500-> 400->400-> 1000 +300 +400
# Out:
# 1700

# %%
t=100
def checkerrornew1(t=900):
    q=300
    r=400
    s=t+q+r
    t=1000
    print(s)
t=500

checkerrornew1(t=200)
#100->900->500--> 200-> 
#conflict of gloabl and local variable and also assigning after expresseion but we have latest value passed as 200 then will consider that to cal expression
# Out:
# 900

# %% [markdown]
# **Return statement**

# %% [markdown]
# - return statement are use to return the value
# - every functions output will save in one variable
# - if we want to use that variable outisde the function then we need to declare as **global** keyword
# - we can also use those variable value using **return**

# %%
def AVERAGE(n1,n2,n3):
    sum= n1+n2+n3
    avg= sum/3
    return avg
abc=AVERAGE(10,20,30)

# %%
abc
# Out:
# 20.0

# %%
def AVERAGE(n1,n2,n3):
    sum= n1+n2+n3
    avg= sum/3
    return(avg,sum)
avg =AVERAGE(10,20,30)

# %%
avg
# Out:
# (20.0, 60)

# %%
def AVERAGE(n1,n2,n3):
    sum= n1+n2+n3
    avg= sum/3
    return avg
AVERAGE(10,20,30)
# Out:
# 20.0

# %%
def AVERAGE(n1,n2,n3):
    sum= n1+n2+n3
    avg= sum/3
    return(avg,sum)
avg,sum =AVERAGE(10,20,30)

# %%
avg,sum
# Out:
# (20.0, 60)

# %%
def greet(name, age):
    print(f'my name is {name} and my age is {age}')

greet('Abcd',30)
# Out:
# my name is Abcd and my age is 30

# %%
def greet(name, age=35):
    print(f'my name is {name} and my age is {age}')

greet('Abcd',40)
# Out:
# my name is Abcd and my age is 40

# %%
def greet(name, age=35):
    age=50
    print(f'my name is {name} and my age is {age}')

greet('Abcd',40)
# Out:
# my name is Abcd and my age is 50

# %%
greet(name='Abcd',40)
# Out:
#   Cell In[4], line 1
#     greet(name='Abcd',40)
#                         ^
# SyntaxError: positional argument follows keyword argument

# %%
greet(name='Abcd',age=40)
# Out:
# my name is Abcd and my age is 50

# %%
greet('Abcd',age=40)
# Out:
# my name is Abcd and my age is 50

# %%
def greet1(name, /,age=35):
    age=50
    print(f'my name is {name} and my age is {age}')

greet1('Abcd',40)
#argument name not given
# Out:
# my name is Abcd and my age is 50

# %%
greet1(name='Abcd',age=40)
#aregument name given -yes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 greet1(name='Abcd',age=40)
#
# TypeError: greet1() got some positional-only arguments passed as keyword arguments: 'name'

# %%
greet1(name='Abcd',40)
#aregument name given before /-yes
# Out:
#   Cell In[9], line 1
#     greet1(name='Abcd',40)
#                          ^
# SyntaxError: positional argument follows keyword argument

# %%
greet1('Abcd',age=40)
#aregument name given after /-yes
# Out:
# my name is Abcd and my age is 50

# %%
greet1(name,/,age)
greet1('Abcd',40)  #w
greet1('Abcd',age=40) #w
greet1(name='Abcd',age=40)  #fail
greet1(name='Abcd',40)  #fail

# %% [markdown]
# **Before / no argument name**
# - before / called **positional arguments**, so no need to give . its postion is fixed
# - after / called **keyword argument** its optional to give argument name, we can and we cant, upto us

# %%
import math  
math.sin(X=90) #f            #math.pow(x,/)
math.sin(90)   #w
# Out:
# 0.8939966636005579

# %%
math.pow(2,3)    #math.pow(x,y,/)
# Out:
# 8.0

# %%
math.pow(x=2,y=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 math.pow(x=2,y=3)
#
# TypeError: math.pow() takes no keyword arguments

# %%
import random
random.randint(10,20)       #no slash
# Out:
# 20

# %%
random.randint(a=10,b=20)
# Out:
# 12

# %%
random.randint(10,b=20)
# Out:
# 12

# %%
random.randint(a=10,20)    #bcz defuat value should be given at last  - first rule
# Out:
#   Cell In[21], line 1
#     random.randint(a=10,20)    #bcz defuat value should be given at last  - first rule
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
def greet2(name,*,age):
    age=50
    print(f'my name is {name} and my age is {age}')

# %%
greet2('abcd',35)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 greet2('abcd',35)
#
# TypeError: greet2() takes 1 positional argument but 2 were given

# %%
greet2(name='abcd',age=35)
# Out:
# my name is abcd and my age is 50

# %%
greet2(name='abcd',35)
# Out:
#   Cell In[25], line 1
#     greet2(name='abcd',35)
#                          ^
# SyntaxError: positional argument follows keyword argument

# %%
greet2('abcd',age=35)
# Out:
# my name is abcd and my age is 50

# %%
greet1(name,*,age)
greet1('Abcd',40)  #f
greet1('Abcd',age=40) #w
greet1(name='Abcd',age=40)  #w
greet1(name='Abcd',40)  #fail
# Out:
#   Cell In[27], line 1
#     greet1(name,*,age)
#                  ^
# SyntaxError: Invalid star expression

# %% [markdown]
# - before * optional
# - after * mandatory

# %% [markdown]
# - **before / no need, After / our wish**
# - **before * our wish, after * mandatory**

# %%
print(type(function))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(type(function))
#
# NameError: name 'function' is not defined

# %%
return
# Out:
#   Cell In[6], line 1
#     return
#     ^
# SyntaxError: 'return' outside function
