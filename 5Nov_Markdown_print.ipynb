# %%
a=10
b=20
c= a+b
print(c)
# Out:
# 30

# %%
n1=100
n1
# Out:
# 100

# %%
a= 'hello, Today I am learning python'
a
# Out:
# 'hello, Today I am learning python'

# %%
a=20
b=40
a
b
#python default show last value , if you wamt to see both then use print
# Out:
# 40

# %%
a=20
b=40
print(a,b)
# Out:
# 20 40

# %%
a=20
b=40
print(a) , print(b) #internet default behaviour, no logic in this
# Out:
# 20
# 40
# (None, None)

# %%
20
# Out:
# 20

# %% [markdown]
# Writing a story in a cell is possible by using markdown mode option. ex. Hello, I am learning python, Its a very interesting and easy

# %% [markdown]
# ESP + M =Markdown mode ==> Shift + enter to run
# Esp + Y =code mode

# %% [markdown]
# # python

# %% [markdown]
# - square brackets indicate mode in code mode
#
# - when square brackets are not there indicates markdown mode
#
# - code mode is to write code
#
# - markdown mode is to document entire thing like a book
#
# - Python is case sensitive

# %% [markdown]
# <img src="https://incubator.ucf.edu/wp-content/uploads/2023/07/artificial-intelligence-new-technology-science-futuristic-abstract-human-brain-ai-technology-cpu-central-processor-unit-chipset-big-data-machine-learning-cyber-mind-domination-generative-ai-scaled-1.jpg" id="img" style="width: 531px; height: 354px;">

# %% [markdown]
# copy image source, paste in cell, chng to markdonw mode and run it
